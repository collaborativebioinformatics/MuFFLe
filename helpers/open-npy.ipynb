# %%
import numpy as np
import os 

print(os.getcwd())
# Load the file
data = np.load('../../rna-cd-data/features-coordinates/3B_426_HE.npy')

print(data.shape)
print(data)
# Out:
# /Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/helpers
# (116382,)
# [(100000, 78912, 224, 0, 1., 230, 0.25)
#  (100000, 79136, 224, 0, 1., 230, 0.25)
#  (100064, 83264, 224, 0, 1., 230, 0.25) ...
#  ( 99872, 99360, 224, 0, 1., 230, 0.25)
#  ( 99872, 99584, 224, 0, 1., 230, 0.25)
#  ( 99872, 99808, 224, 0, 1., 230, 0.25)]

# %%
print(data[0])
# Out:
# (100000, 78912, 224, 0, 1.0, 230, 0.25)
